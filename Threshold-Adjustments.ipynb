# %% [markdown]
# # Eşik Ayarlaması

# %% [markdown]
# 👇 Çalışacağınız veri setini görmek için `player_performances.csv` oyuncu veri setini yükleyin.

# %%
import pandas as pd

# !curl -s https://d32aokrjazspmn.cloudfront.net/materials/ML_Player_performance.csv > data/player_performances.csv

data = pd.read_csv('data/player_performances.csv')

data.head()
# Out:
#    games played  minutes played  points per game  field goals made  \
# 0            36            27.4              7.4               2.6
# 1            35            26.9              7.2               2.0
# 2            74            15.3              5.2               2.0
# 3            58            11.6              5.7               2.3
# 4            48            11.5              4.5               1.6
#
#    field goal attempts  field goal percent  3 point made  3 point attempt  \
# 0                  7.6                34.7           0.5              2.1
# 1                  6.7                29.6           0.7              2.8
# 2                  4.7                42.2           0.4              1.7
# 3                  5.5                42.6           0.1              0.5
# 4                  3.0                52.4           0.0              0.1
#
#    3 point %  free throw made  free throw attempts  free throw %  \
# 0       25.0              1.6                  2.3          69.9
# 1       23.5              2.6                  3.4          76.5
# 2       24.4              0.9                  1.3          67.0
# 3       22.6              0.9                  1.3          68.9
# 4        0.0              1.3                  1.9          67.4
#
#    offensive rebounds  defensive rebounds  rebounds  assists  steals  blocks  \
# 0                 0.7                 3.4       4.1      1.9     0.4     0.4
# 1                 0.5                 2.0       2.4      3.7     1.1     0.5
# 2                 0.5                 1.7       2.2      1.0     0.5     0.3
# 3                 1.0                 0.9       1.9      0.8     0.6     0.1
# 4                 1.0                 1.5       2.5      0.3     0.3     0.4
#
#    turnovers  target_5y
# 0        1.3          0
# 1        1.6          0
# 2        1.0          0
# 3        1.0          1
# 4        0.8          1

# %% [markdown]
# ℹ️ Her gözlem bir oyuncuyu temsil eder ve her sütun performansın bir özelliğidir. Hedef `target_5y`, oyuncunun 5 yıldan az [0] veya 5 yıl ve daha fazla [1] profesyonel kariyere sahip olup olmadığını tanımlar.

# %% [markdown]
# # Ön İşleme

# %% [markdown]
# 👇 Ön işleme için çok fazla zaman harcamamak adına, tüm özellik setini Robust Scale ile ölçeklendirin. Bu uygulama optimal değildir, ancak ön işleme ve/veya modellerin hızla çalıştırılması için kullanılabilir.
#
# Ölçeklendirilmiş özellik setini `X_scaled` olarak kaydedin.

# %%
from sklearn.preprocessing import RobustScaler

# 1. Özellikleri (X) ve hedef değişkeni (y) ayıralım
# 'target_5y' sütununu tahmin edeceğimiz için onu X'ten çıkarıyoruz
X = data.drop(columns=['target_5y'])
y = data['target_5y']

# 2. RobustScaler nesnesini tanımlayalım
scaler = RobustScaler()

# 3. Özellikleri ölçeklendirelim ve X_scaled değişkenine atayalım
X_scaled = scaler.fit_transform(X)

print("✅ Özellikler RobustScaler ile başarıyla ölçeklendirildi!")
# Out:
# ✅ Özellikler RobustScaler ile başarıyla ölçeklendirildi!

# %% [markdown]
# ### ☑️ Kodunuzu kontrol edin

# %%
from nbresult import ChallengeResult

result = ChallengeResult('scaled_features',
                         scaled_features = X_scaled
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/macos/.pyenv/versions/3.12.9/envs/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/macos/Desktop/S16D3-S-data-threshold/tests
# plugins: dash-4.0.0, anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_scaled_features.py::TestScaled_features::test_scaled_features PASSED [100%]
#
# ============================== 1 passed in 0.18s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/scaled_features.pickle
#
# git commit -m 'Completed scaled_features step'
#
# git push origin master

# %% [markdown]
# # Temel Modelleme

# %% [markdown]
# 🎯 Görev, %90 garantiyle minimum 5 yıl profesyonel olarak devam edecek oyuncuları tespit etmektir.
#
# 👇 Varsayılan bir Lojistik Regresyon modeli antrenörün gereksinimlerini karşılayacak mı? Çapraz doğrulama kullanın ve cevabınızı destekleyen skoru `base_score` değişken adı altında kaydedin.

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_validate

# 1. Lojistik Regresyon modelini tanımlıyoruz
model = LogisticRegression()

# 2. Antrenörün 'garanti' isteği Precision (Hassasiyet) olduğu için bu metriği ölçüyoruz
cv_results = cross_validate(model, X_scaled, y, cv=5, scoring='precision')

# 3. Sonucu base_score olarak kaydediyoruz
base_score = cv_results['test_score'].mean()

print(f"🏀 Standart modelin güven (Precision) skoru: %{base_score*100:.2f}")
# Out:
# 🏀 Standart modelin güven (Precision) skoru: %73.79

# %% [markdown]
# ### ☑️ Kodunuzu kontrol edin

# %%
from nbresult import ChallengeResult

result = ChallengeResult('base_precision',
                         score = base_score
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/macos/.pyenv/versions/3.12.9/envs/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/macos/Desktop/S16D3-S-data-threshold/tests
# plugins: dash-4.0.0, anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_base_precision.py::TestBase_precision::test_precision_score PASSED  [100%]
#
# ============================== 1 passed in 0.17s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/base_precision.pickle
#
# git commit -m 'Completed base_precision step'
#
# git push origin master

# %% [markdown]
# # Eşik Ayarlaması

# %% [markdown]
# 👇 Bir oyuncunun profesyonel olarak 5 yıl veya daha fazla sürmesi için %90 kesinlik garantisi veren karar eşiğini bulun. Eşiği `new_threshold` değişken adı altında kaydedin.

# %% [markdown]
# <details>
# <summary>💡 İpucu</summary>
#
# - [`cross_val_predict`](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.cross_val_predict.html) ile çapraz doğrulanmış olasılık tahminleri yapın
#
# - Farklı eşiklerde kesinlik skorları oluşturmak için olasılıkları [`precision_recall_curve`](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.precision_recall_curve.html) içine yerleştirin
#
# - 0.9 kesinliği garanti eden eşiği bulun
#
# </details>

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.model_selection import cross_val_predict

# 1. Tüm oyuncular için 5 yıl kalma olasılıklarını (probability) alıyoruz
y_probas = cross_val_predict(model, X_scaled, y, cv=5, method='predict_proba')
# Sadece '1' olma (yıldız olma) olasılıklarını seçiyoruz
y_scores = y_probas[:, 1]

# 2. Farklı eşik değerlerine göre Precision ve Recall değerlerini hesaplıyoruz
precisions, recalls, thresholds = precision_recall_curve(y, y_scores)

# 3. Hassasiyetin (Precision) en az %90 (0.90) olduğu ilk eşik değerini buluyoruz
# (Not: precision listesi thresholds listesinden 1 eleman uzundur, bu yüzden [:-1] kullanıyoruz)
new_threshold = thresholds[precisions[:-1] >= 0.90][0]

print(f"🎯 %90 güven sağlayan yeni karar eşiği (new_threshold): {new_threshold:.4f}")
# Out:
# 🎯 %90 güven sağlayan yeni karar eşiği (new_threshold): 0.8667

# %% [markdown]
# ### ☑️ Kodunuzu kontrol edin

# %%
from nbresult import ChallengeResult

result = ChallengeResult('decision_threshold',
                         threshold = new_threshold
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/macos/.pyenv/versions/3.12.9/envs/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/macos/Desktop/S16D3-S-data-threshold/tests
# plugins: dash-4.0.0, anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_decision_threshold.py::TestDecision_threshold::test_new_threshold PASSED [100%]
#
# ============================== 1 passed in 0.18s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/decision_threshold.pickle
#
# git commit -m 'Completed decision_threshold step'
#
# git push origin master

# %% [markdown]
# # Yeni Eşiği Kullanma

# %% [markdown]
# 🎯 Antrenör potansiyel olarak ilginç bir oyuncu fark etti, ancak bu oyuncunun minimum 5 yıl profesyonel olarak devam edeceğine dair %90 garantinizi istiyor. Oyuncunun verilerini [buradan](https://wagon-public-datasets.s3.amazonaws.com/Machine%20Learning%20Datasets/ML_New_player.csv) indirin.

# %%
import urllib3
urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

# %%
import pandas as pd
import requests
import io

# SSL kontrolünü devre dışı bırakarak veriyi internetten çekiyoruz
url = "https://d32aokrjazspmn.cloudfront.net/materials/ML_New_player.csv"
s = requests.get(url, verify=False).content

# Çektiğimiz veriyi Pandas dataframe'ine dönüştürüyoruz
new_player = pd.read_csv(io.StringIO(s.decode('utf-8')))

display(new_player)
# Out:
#    games played  minutes played  points per game  field goals made  \
# 0            80            31.4             14.3               5.9
#
#    field goal attempts  field goal percent  3 point made  3 point attempt  \
# 0                 11.1                52.5           0.0              0.1
#
#    3 point %  free throw made  free throw attempts  free throw %  \
# 0       11.1              2.6                  3.9          65.4
#
#    offensive rebounds  defensive rebounds  rebounds  assists  steals  blocks  \
# 0                 3.0                 5.0       8.0      2.4     1.1     0.8
#
#    turnovers
# 0        2.2

# %% [markdown]
# ❓ Oyuncuyu antrenöre tavsiye etmeyi göze alır mısınız? Cevabınızı string olarak `recommendation` değişken adı altında "recommend" veya "not recommend" şeklinde kaydedin.

# %%
# 1. ÖNEMLİ: Modeli tüm ölçeklenmiş veriyle eğitelim (Bu adım eksikti)
model.fit(X_scaled, y)

# 2. Yeni oyuncu verisini ölçeklendiriyoruz
new_player_scaled = scaler.transform(new_player)

# 3. Oyuncunun 5 yıl kariyer yapma olasılığını buluyoruz (1 olma ihtimali)
new_player_proba = model.predict_proba(new_player_scaled)[0][1]

# 4. Antrenörün %90 güven şartına (new_threshold) uyuyor mu?
if new_player_proba >= new_threshold:
    recommendation = "recommend"
else:
    recommendation = "not recommend"

print(f"🏀 Oyuncunun 5 Yıl Profesyonel Kalma Olasılığı: %{new_player_proba*100:.2f}")
print(f"🎯 Antrenöre Kararımız: {recommendation}")
# Out:
# 🏀 Oyuncunun 5 Yıl Profesyonel Kalma Olasılığı: %94.56
# 🎯 Antrenöre Kararımız: recommend

# %% [markdown]
# ### ☑️ Kodunuzu kontrol edin

# %%
from nbresult import ChallengeResult

result = ChallengeResult('recommendation',
                         recommendation = recommendation
)

result.write()
print(result.check())
# Out:
# ============================= test session starts ==============================
# platform darwin -- Python 3.12.9, pytest-8.3.4, pluggy-1.5.0 -- /Users/macos/.pyenv/versions/3.12.9/envs/workintech/bin/python
# cachedir: .pytest_cache
# rootdir: /Users/macos/Desktop/S16D3-S-data-threshold/tests
# plugins: dash-4.0.0, anyio-4.8.0, typeguard-4.4.2
# collecting ... collected 1 item
#
# test_recommendation.py::TestRecommendation::test_recommendation PASSED   [100%]
#
# ============================== 1 passed in 0.02s ===============================
#
#
# 💯 You can commit your code:
#
# git add tests/recommendation.pickle
#
# git commit -m 'Completed recommendation step'
#
# git push origin master

# %% [markdown]
# # 🏁
